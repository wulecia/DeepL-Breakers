# %% [markdown]
# ✅ Loaded model from checkpoint2.pt
# 📚 Epoch 1: Train Loss = 0.8478, Val Loss = 0.8818
# 📚 Epoch 2: Train Loss = 0.8160, Val Loss = 0.8974
# 📚 Epoch 3: Train Loss = 0.7938, Val Loss = 0.9163
# 📚 Epoch 4: Train Loss = 0.7742, Val Loss = 0.9341
# ⏹️ Early stopping after 4 epochs
#
#
# 📊 Regression (Numerical):
# • R² Score: 0.5312
# • MSE: 0.6873
#
# ⚖️ Classification (Binary):
# • Accuracy: 0.7029
# • F1 Macro: 0.8079
# • F1 Micro: 0.8174

# %% [markdown]
# batch normalization
# augmenter dropout
# diminuer le nombre de neurones
# library optuna : gridsearch en mieux

# %% [markdown]
# Epoch 1: Train Loss = 1.2380, Val Loss = 0.9177
# Best model saved as results/best_model_2025-05-21_14-15-59.pth
# Epoch 2: Train Loss = 0.9631, Val Loss = 0.8759
# Best model saved as results/best_model_2025-05-21_14-23-53.pth
# Epoch 3: Train Loss = 0.8879, Val Loss = 0.8855
# Epoch 4: Train Loss = 0.8420, Val Loss = 0.8897
# Epoch 5: Train Loss = 0.8128, Val Loss = 0.9144
# Early stopping after 5 epochs
